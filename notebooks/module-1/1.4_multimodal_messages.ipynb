# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="claude-haiku-4-5-20251001", #gpt-5-nano
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# # Lunar Prime
#
# **The Moon's Capital City**
#
# Nestled within the reinforced mega-cavern of the **Tycho Depths**, 4 kilometers beneath the lunar surface, sits **Lunar Prime**—humanity's first off-world capital.
#
# ## Key Features:
#
# **Architecture & Layout**
# - Built around a central crystalline spire that serves as both government seat and communications hub
# - Concentric rings of residential, industrial, and agricultural domes connected by pressurized transit tubes
# - Bioluminescent flora—genetically engineered for human environments—illuminates the cavern ceiling
#
# **Population**: ~2.3 million inhabitants
#
# **Government**: The Lunar Council, a democratic federation of residential sectors, oversees policy with Earth's remote oversight
#
# **Economy**: Mining rare earth elements, helium-3 extraction, and manufacturing in low-gravity conditions
#
# **Notable Districts**
# - *The Promenade*: Zero-gravity recreational sphere
# - *Garden Sector*: Massive hydroponic farms producing oxygen and food
# - *Tech Nexus*: Research hubs for quantum computing and propulsion systems
# - *Exile Quarter*: Independent merchants and entrepreneurs operating semi-legally
#
# **Challenge**: Life support systems require constant maintenance. A catastrophic failure in 2247 nearly forced evacuation before repairs were completed.
#
# Would you like me to develop a specific aspect of Lunar Prime further—its politics, history, or perhaps a neighboring colony?

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x11d694dc0>, 'last_modified': datetime.datetime(2026, 9, 18, 3, 40, 28, 98000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# # Aethermoor: The Crystalline Capital
#
# ## Overview
# Nestled in the shadow of the binary moon system, **Aethermoor** rises from the Karos Basin like a luminescent crown of impossible geometry. This capital of the Valorian Confederation represents humanity's most ambitious extraterrestrial settlement, built across three planetary bodies connected by gravity-thread suspension bridges.
#
# ## Architecture & Geography
#
# **The Spire Districts** - The iconic vertical towers pierce through the thin atmosphere, their bio-metallic surfaces shifting between iridescent blues and purples. Each spire serves as a self-contained city module with rotating habitation rings.
#
# **The Resonance Valleys** - Between towering rock formations, mirror-smooth lakes of liquid helium-3 reflect the twin moons above. These valleys house the city's primary power generation through tidal harmonic collectors.
#
# **The Undercroft** - Vast carved chambers beneath the surface serve as manufacturing, agriculture, and cultural centers. The bioluminescent cavern walls were cultivated from native crystalline organisms.
#
# ## Key Features
#
# - **Population**: 4.2 million (70% human, 30% synthetic/hybrid)
# - **Primary Industries**: Stellar navigation tech, quantum computing, exotic matter refinement
# - **Climate Control**: Atmospheric processors regulate the thin air; residents rarely need suits in city limits
# - **Transportation**: Magnetic rail networks, personal hover-pods, and the famous Void Trams between districts
#
# The city never truly sleeps—with three suns and dual moons creating perpetual twilight, Aethermoor exists in a state of eternal transition.
#
# **What aspect interests you most?**

# %% [markdown]
# ## Audio input

# %%
# %pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.70.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 3.2 MB/s eta 0:00:00
# Downloading tqdm-4.70.1-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: tqdm
# Successfully installed tqdm-4.70.1
#
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.65it/s]
# Done.

# %%
agent = create_agent(
    model='gemini-1.5-flash', #'gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/google/cloud/aiplatform/initializer.py:363, in _Config.project(self)
#     362 try:
# --> 363     self._set_project_as_env_var_or_google_auth_default()
#     364     project_id = self._project
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/google/cloud/aiplatform/initializer.py:97, in _Config._set_project_as_env_var_or_google_auth_default(self)
#      96 if not self._credentials:
# ---> 97     credentials, _ = google.auth.default(
#      98         scopes=constants.DEFAULT_AUTHED_SCOPES
#      99     )
#     100     self._credentials = credentials
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/google/auth/_default.py:748, in default(scopes, request, quota_project_id, default_scopes)
#     746         return credentials, effective_project_id
# --> 748 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# The above exception was the direct cause of the following exception:
#
# GoogleAuthError                           Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 agent = create_agent(
#       2     model='gemini-1.5-flash', #'gpt-audio',
#       3 )
#       4
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/agents/factory.py:996, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache, transformers)
#     994 # init chat model
#     995 if isinstance(model, str):
# --> 996     model = init_chat_model(model)
#     998 # Convert system_prompt to SystemMessage if needed
#     999 system_message: SystemMessage | None = None
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:516, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     508     warnings.warn(
#     509         f"{config_prefix=} has been set but no fields are configurable. Set "
#     510         f"`configurable_fields=(...)` to specify the model params that are "
#     511         f"configurable.",
#     512         stacklevel=2,
#     513     )
#     515 if not configurable_fields:
# --> 516     return _init_chat_model_helper(
#     517         cast("str", model),
#     518         model_provider=model_provider,
#     519         **kwargs,
#     520     )
#     521 if model:
#     522     kwargs["model"] = model
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:540, in _init_chat_model_helper(model, model_provider, **kwargs)
#     538 model, model_provider = _parse_model(model, model_provider)
#     539 creator_func = _get_chat_model_creator(model_provider)
# --> 540 return creator_func(model=model, **kwargs)
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:53, in _call(cls, **kwargs)
#      51 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      52     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 53     return cls(**kwargs)
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:274, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     271     # Only mark the warning as emitted if it was not intentionally
#     272     # suppressed by `suppress_langchain_deprecation_warning()`.
#     273     warned = not _SUPPRESSING_LANGCHAIN_DEPRECATION_WARNING.get()
# --> 274 return wrapped(self, *args, **kwargs)
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_google_vertexai/chat_models.py:1943, in ChatVertexAI.__init__(self, model_name, **kwargs)
#    1937         suggestion = (
#    1938             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1939         )
#    1940         logger.warning(
#    1941             f"Unexpected argument '{arg}' provided to ChatVertexAI.{suggestion}"
#    1942         )
# -> 1943 super().__init__(**kwargs)
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/load/serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_google_vertexai/_base.py:156, in _VertexAIBase.validate_project(self)
#     154         self.project = self.credentials.project_id
#     155     else:
# --> 156         self.project = initializer.global_config.project
#     157 return self
#
# File ~/PycharmProjects/lca-lc-foundations/.venv/lib/python3.12/site-packages/google/cloud/aiplatform/initializer.py:366, in _Config.project(self)
#     364     project_id = self._project
#     365 except GoogleAuthError as exc:
# --> 366     raise GoogleAuthError(project_not_found_exception_str) from exc
#     368 if not project_id and not self.api_key:
#     369     raise ValueError(project_not_found_exception_str)
#
# GoogleAuthError: Unable to find your project. Please provide a project ID by:
# - Passing a constructor argument
# - Using vertexai.init()
# - Setting project using 'gcloud config set project my-project'
# - Setting a GCP environment variable
# - To create a Google Cloud project, please follow guidance at https://developers.google.com/workspace/guides/create-project
