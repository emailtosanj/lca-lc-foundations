# %%
#Jai Shri Ram

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
# package.module <langchain.chat_models import init_chat_model>
from langchain.chat_models import init_chat_model

#model = init_chat_model(model="gpt-5-nano")
model = init_chat_model(model="claude-haiku-4-5-20251001")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# AIMessage(content="The Moon doesn't have a capital because it's not a country or political entity. It's Earth's natural satellite.\n\nIf you're interested in lunar exploration, the closest thing might be reference to major landing sites like the Apollo landing areas or research bases that various space agencies have proposed for future missions.\n\nIs there something specific about the Moon you'd like to know about?", additional_kwargs={}, response_metadata={'id': 'msg_011Cf9GfjemGx6ywvUSprpGz', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 15, 'output_tokens': 79, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--01a0b00b-7b07-71a0-bc68-eacfc608f59f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 79, 'total_tokens': 94, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or political entity. It's Earth's natural satellite.
#
# If you're interested in lunar exploration, the closest thing might be reference to major landing sites like the Apollo landing areas or research bases that various space agencies have proposed for future missions.
#
# Is there something specific about the Moon you'd like to know about?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'container': None,
#  'id': 'msg_011Cf9GfjemGx6ywvUSprpGz',
#  'model': 'claude-haiku-4-5-20251001',
#  'model_name': 'claude-haiku-4-5-20251001',
#  'model_provider': 'anthropic',
#  'stop_details': None,
#  'stop_reason': 'end_turn',
#  'stop_sequence': None,
#  'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0,
#                               'ephemeral_5m_input_tokens': 0},
#            'cache_creation_input_tokens': 0,
#            'cache_read_input_tokens': 0,
#            'inference_geo': 'not_available',
#            'input_tokens': 15,
#            'output_tokens': 79,
#            'output_tokens_details': None,
#            'server_tool_use': None,
#            'service_tier': 'standard'}}

# %% [markdown]
# ## Customising your Model

# %%
# model = init_chat_model(
#     model="gpt-5-nano",
#     # Kwargs passed to the model:
#     temperature=1.0
# )

#claude-haiku-4-5-20251001
model = init_chat_model(model="claude-haiku-4-5-20251001", temperature=1.0)


response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# The Moon doesn't have a capital because it's not a country or organized political entity. It's a natural satellite of Earth with no permanent human settlements or government.
#
# However, if you're asking this as a playful question, the answer would be "nowhere" or "space"! Is there something specific about the Moon you'd like to know about?
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# The Moon doesn't have a capital city. It has no permanent human settlements, government, or political divisions. It is a natural satellite with no indigenous population.
#
# There have been various lunar landings and robotic missions, but no established cities or capitals exist there.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, cities, or sovereign nations. Under the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no country can claim sovereignty over the Moon or any other celestial body.\n\nWhile there are many scientific research bases and lunar landers scattered across the surface, they are operated by various national space agencies (such as NASA, CNSA, or ISRO) or private companies, and they do not function as administrative capitals.', 'extras': {'signature': 'EnEKbwERTTIP41pmu9aZBpeYD8/OTl24l5icw7/M1v36XjzRKsDA9gHl6Yy4U1NTFBhNLHHPPf0tctPvQxEvs14eO/utDGXHxXFpS64RyWLnsaJPR3vvUbLe+K1cNN/SiKIEsZOfIzkzBaCpgCyJwmEoKQ=='}}]
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print(response.response_metadata)
# Out:
# {'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
print(model)
# Out:
# metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0'}} profile={} google_api_key=SecretStr('**********') model='gemini-3.1-flash-lite' temperature=1.0 client=<google.genai.client.Client object at 0x12384b230> default_metadata=() model_kwargs={}

# %%
agent = create_agent(model="claude-sonnet-4-6")

# %%
#agent = create_agent("gpt-5-nano")

# %%
print(response.response_metadata)
# Out:
# {'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}

# %%
from pprint import pprint

pprint(response)
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, cities, or sovereign nations. Under the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no country can claim sovereignty over the Moon or any other celestial body.\n\nWhile there are many scientific research bases and lunar landers scattered across the surface, they are operated by various national space agencies (such as NASA, CNSA, or ISRO) or private companies, and they do not function as administrative capitals.', 'extras': {'signature': 'EnEKbwERTTIP41pmu9aZBpeYD8/OTl24l5icw7/M1v36XjzRKsDA9gHl6Yy4U1NTFBhNLHHPPf0tctPvQxEvs14eO/utDGXHxXFpS64RyWLnsaJPR3vvUbLe+K1cNN/SiKIEsZOfIzkzBaCpgCyJwmEoKQ=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b00e-d644-7332-9843-3a6bbface7f4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 108, 'total_tokens': 118, 'input_token_details': {'cache_read': 0}})

# %%
print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(response['messages'][-1].content)
#
# TypeError: 'AIMessage' object is not subscriptable

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='02386b1f-fa6d-4afd-a86a-0d60af287b15'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='36c7688e-2c3f-4f42-96db-1b75ba0a944f', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='a40b9c9f-3ee6-4231-8b06-4b3d9027118b'),
#               AIMessage(content="I need to correct myself - I apologize for my previous response. **There is no capital of the Moon.** The Moon has no capital city because it has no government or permanent human settlement.\n\nLuna City is a fictional place that appears in various science fiction stories, such as Robert A. Heinlein's works, but it does not actually exist.\n\nAs of now, no humans live permanently on the Moon. There have been crewed missions, most notably NASA's Apollo missions (1969-1972), but no lasting colonies or cities have been established there. Various space agencies have discussed plans for future lunar bases, but none exist yet.\n\nI should not have made up an answer to your original question. I'm sorry for the confusion.", additional_kwargs={}, response_metadata={'id': 'msg_011Cf9HJzQoRZn9k47egx12u', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 39, 'output_tokens': 158, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--01a0b013-3182-7ff0-ba4a-d6641b4b4e71-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 158, 'total_tokens': 197, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# I want to be straightforward with you: **Luna City does not exist**. There is no capital city on the Moon.
#
# As of now:
#
# - **No permanent human settlement exists on the Moon**
# - The Moon has no government, capital, or inhabited cities
# - Only **12 humans have ever walked on the Moon**, all during NASA's Apollo missions (1969-1972), and none stayed permanently
# - Various space agencies and private companies have **plans and proposals** for future lunar bases, but none have been built
#
# ## What Does Exist on the Moon
#
# - **Scientific equipment** left from Apollo missions
# - **Robotic landers and rovers** from various countries
# - **Lunar orbiters** currently operating
# - The **Artemis program** (NASA) aims to return humans to the Moon, potentially establishing a future base
#
# ## "Luna City" in Fiction
#
# Luna City appears in various science fiction works, including:
# - **Robert Heinlein's** stories
# - Various video games and novels
#
# If you're interested in **real lunar exploration plans**, **science fiction depictions**, or something else related to the Moon, I'm happy to discuss any of those honestly.
#
# Is there something specific you were curious about?
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
