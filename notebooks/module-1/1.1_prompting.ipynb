# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent #this creates agent
from langchain.messages import HumanMessage #this is a HumanMessage

# agent = create_agent(model="gpt-5-nano")
agent = create_agent(model="claude-haiku-4-5-20251001")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

print(type(response))
# Out:
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# The Moon doesn't have a capital because it's not a country or organized political entity. It's a natural satellite of Earth with no permanent human settlements or government.
#
# If you're thinking of a fictional scenario or a creative question, I'd be happy to help with that! Or if you meant something else, feel free to clarify.
# <class 'dict'>
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print(response.keys())
# Out:
# dict_keys(['messages'])

# %%
print(response['messages'][1])
# Out:
# content="The Moon doesn't have a capital because it's not a country or organized political entity. It's a natural satellite of Earth with no permanent human settlements or government.\n\nIf you're thinking of a fictional scenario or a creative question, I'd be happy to help with that! Or if you meant something else, feel free to clarify." additional_kwargs={} response_metadata={'id': 'msg_011Cf9xRBeBkVhtZMvxXoZDn', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 15, 'output_tokens': 72, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'} id='lc_run--01a0b1e8-b462-7941-8921-38daf825a87d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 72, 'total_tokens': 87, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}

# %%
print(type(question))
print(question)
# Out:
# <class 'langchain_core.messages.human.HumanMessage'>
# content="What's the capital of the moon?" additional_kwargs={} response_metadata={} id='f5ab098e-8086-45cd-97f9-928ce77bb3a0'

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

# scifi_agent = create_agent(
#     model="gpt-5-nano",
#     system_prompt=system_prompt
# )


scifi_agent = create_agent(
    model="claude-haiku-4-5-20251001",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# # Selene Prime
#
# Nestled in the vast Sinus Iridum basin on the Moon's northern hemisphere, **Selene Prime** has grown into humanity's largest lunar settlement and the de facto capital of the Moon.
#
# ## Key Features
#
# **Architecture & Design**
# - Most structures are built partially subterranean to protect from radiation and temperature extremes
# - Distinctive white and silver domes connected by pressurized transit tubes create a gleaming appearance visible from Earth with enhancement
# - The central Governmental Spire rises 40 meters above the regolith, its exterior layered with heat-reflective panels
#
# **Government**
# - Governed by the Lunar Colonial Council—a rotating leadership of representatives from each major settlement
# - The Hall of Consensus serves as the primary legislative building
#
# **Economy**
# - Primary industries: rare earth element mining, helium-3 extraction for fusion reactors, and scientific research
# - The Selene Station serves as the primary dock for cargo vessels from Earth and Mars
#
# **Notable Districts**
# - **New Tranquility**: The oldest residential sector, built around the first permanent settlement
# - **The Void Markets**: A bustling underground bazaar where goods from across the solar system are traded
# - **Observatory Ridge**: Home to advanced telescopes studying deep space
#
# **Population**: ~287,000 permanent residents
#
# Would you like me to detail any particular aspect of Selene Prime further?
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print(type(response['messages'][1]))
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="claude-haiku-4-5-20251001", #gpt-5-nano
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# # Selenopolis
#
# A sprawling lunar metropolis nestled within the massive Tycho Crater, Selenopolis serves as humanity's first true off-world capital. Its gleaming domes and underground cavern-cities house over 2 million inhabitants, connected by a network of magnetic transit tubes that snake across the lunar surface.
#
# The city is renowned for its zero-gravity manufacturing districts, its magnificent observation platforms overlooking Earth, and the iconic Tranquility Monument at its center—a tribute to the first lunar landing.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print(question)
# Out:
# content="What's the capital of the moon?" additional_kwargs={} response_metadata={} id='f5ab098e-8086-45cd-97f9-928ce77bb3a0'

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="claude-haiku-4-5-20251001",  #gpt-5-nano
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# # Lunar Prime
#
# **Name:** Lunar Prime
#
# **Location:** Tycho Crater, Moon (Earth's Moon)
#
# **Vibe:** Industrial, ambitious, moonlit
#
# **Economy:** Helium-3 extraction and fusion energy production, rare earth mineral mining, orbital shipyard construction, Earth-to-Moon logistics hub, research and development
#
# ---
#
# Lunar Prime sprawls across the crater floor with interconnected pressurized domes and underground caverns. Its economy thrives on harvesting the Moon's abundant resources—particularly helium-3 for clean energy back on Earth. The city serves as the primary staging ground for deep space missions and hosts cutting-edge research facilities studying everything from low-gravity manufacturing to lunar geology. Constant activity from mining operations and interplanetary commerce gives it a relentless, forward-thinking atmosphere.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='claude-haiku-4-5-20251001', #gpt-5-nano
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# CapitalInfo(name='Lunaria Prime', location='Tycho Crater, The Moon', vibe='Sleek, sterile, and neon-lit with transparent domes revealing star-filled skies; a bustling hub where Earth colonists and lunar natives coexist in pressurized habitats', economy='Built on helium-3 mining, rare earth element extraction, and zero-gravity manufacturing; a thriving trade hub for interplanetary commerce and scientific research')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
response["structured_response"].name
# Out:
# 'Lunaria Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaria Prime is a city located at Tycho Crater, The Moon
